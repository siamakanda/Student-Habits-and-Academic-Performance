# %% [markdown]
# <a href="https://colab.research.google.com/github/siamakanda/Student-Habits-and-Academic-Performance/blob/main/Student%20Habits%20and%20Academic%20Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Student Habits and Academic Performance Dataset
#
# ## 📘 Dataset Overview
# This synthetic dataset simulates the academic and lifestyle behaviors of 80,000 students, including diverse features like study habits, mental health, family background, motivation, and environmental factors. The goal is to explore how different variables affect student performance in terms of GPA and exam scores.

# %% [markdown]
# **Imports and Setup.**

# %%
# Import and Setup!
import pandas as pd
import numpy as np

# File Path!
# file_path = r'E:\Environment\Data Science\Mini Exercise Project 1\enhanced_student_habits_performance_dataset\enhanced_student_habits_performance_dataset.csv'

file_path = r'enhanced_student_habits_performance_dataset/enhanced_student_habits_performance_dataset.csv'

# file_path = r'https://raw.githubusercontent.com/siamakanda/Student-Habits-and-Academic-Performance/refs/heads/main/enhanced_student_habits_performance_dataset/enhanced_student_habits_performance_dataset.csv'

# %% [markdown]
# # Part 1: Getting Started and Data Inspection
# **How do you load the enhanced_student_habits_performance_dataset.csv file into a Pandas DataFrame?**

# %%
# Try loading from local path, if not found, load from URL
try:
	df = pd.read_csv(file_path)
except FileNotFoundError:
	url = 'https://raw.githubusercontent.com/siamakanda/Student-Habits-and-Academic-Performance/refs/heads/main/enhanced_student_habits_performance_dataset/enhanced_student_habits_performance_dataset.csv'
	df = pd.read_csv(url)
df
# Out:
#        student_id  age  gender             major  study_hours_per_day  \
# 0          100000   26    Male  Computer Science             7.645367
# 1          100001   28    Male              Arts             5.700000
# 2          100002   17    Male              Arts             2.400000
# 3          100003   27   Other        Psychology             3.400000
# 4          100004   25  Female          Business             4.700000
# ...           ...  ...     ...               ...                  ...
# 79995      179995   16    Male       Engineering             3.700000
# 79996      179996   16  Female          Business             1.200000
# 79997      179997   26  Female              Arts             4.100000
# 79998      179998   23   Other           Biology             3.800000
# 79999      179999   25   Other       Engineering             3.000000
#
#        social_media_hours  netflix_hours part_time_job  attendance_percentage  \
# ...

# %% [markdown]
# **How do you display the first 5 rows of the DataFrame?**

# %%
df.head()
# Out:
#    student_id  age  gender             major  study_hours_per_day  \
# 0      100000   26    Male  Computer Science             7.645367
# 1      100001   28    Male              Arts             5.700000
# 2      100002   17    Male              Arts             2.400000
# 3      100003   27   Other        Psychology             3.400000
# 4      100004   25  Female          Business             4.700000
#
#    social_media_hours  netflix_hours part_time_job  attendance_percentage  \
# 0                 3.0            0.1           Yes                   70.3
# 1                 0.5            0.4            No                   88.4
# 2                 4.2            0.7            No                   82.1
# 3                 4.6            2.3           Yes                   79.3
# 4                 0.8            2.7           Yes                   62.9
#
#    sleep_hours  ... screen_time  study_environment access_to_tutoring  \
# ...

# %% [markdown]
# **How do you display the last 10 rows of the DataFrame?**

# %%
df.tail(10)
# Out:
#        student_id  age  gender             major  study_hours_per_day  \
# 79990      179990   25    Male       Engineering             2.200000
# 79991      179991   24  Female       Engineering             0.000000
# 79992      179992   20   Other  Computer Science             5.627152
# 79993      179993   28    Male              Arts             1.300000
# 79994      179994   24   Other          Business             3.800000
# 79995      179995   16    Male       Engineering             3.700000
# 79996      179996   16  Female          Business             1.200000
# 79997      179997   26  Female              Arts             4.100000
# 79998      179998   23   Other           Biology             3.800000
# 79999      179999   25   Other       Engineering             3.000000
#
#        social_media_hours  netflix_hours part_time_job  attendance_percentage  \
# 79990                 2.4            3.2           Yes                   89.8
# ...

# %% [markdown]
# **How do you get a concise summary of the DataFrame, including data types and non-null values?**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80000 entries, 0 to 79999
# Data columns (total 31 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     80000 non-null  int64
#  1   age                            80000 non-null  int64
#  2   gender                         80000 non-null  object
#  3   major                          80000 non-null  object
#  4   study_hours_per_day            80000 non-null  float64
#  5   social_media_hours             80000 non-null  float64
#  6   netflix_hours                  80000 non-null  float64
#  7   part_time_job                  80000 non-null  object
#  8   attendance_percentage          80000 non-null  float64
#  9   sleep_hours                    80000 non-null  float64
#  10  diet_quality                   80000 non-null  object
#  11  exercise_frequency             80000 non-null  int64
# ...

# %% [markdown]
# **What are the dimensions (number of rows and columns) of the DataFrame?**

# %%
df.shape
# Out:
# (80000, 31)

# %% [markdown]
# **How do you list all the column names in the DataFrame?**

# %%
df.columns.tolist()
# Out:
# ['student_id',
#  'age',
#  'gender',
#  'major',
#  'study_hours_per_day',
#  'social_media_hours',
#  'netflix_hours',
#  'part_time_job',
#  'attendance_percentage',
#  'sleep_hours',
#  'diet_quality',
#  'exercise_frequency',
#  'parental_education_level',
#  'internet_quality',
#  'mental_health_rating',
#  'extracurricular_participation',
#  'previous_gpa',
#  'semester',
#  'stress_level',
#  'dropout_risk',
#  'social_activity',
#  'screen_time',
#  'study_environment',
#  'access_to_tutoring',
#  'family_income_range',
#  'parental_support_level',
#  'motivation_level',
#  'exam_anxiety_score',
#  'learning_style',
#  'time_management_score',
#  'exam_score']

# %% [markdown]
# **How do you check the data type of each column?**

# %%
df.dtypes
# Out:
# student_id                         int64
# age                                int64
# gender                            object
# major                             object
# study_hours_per_day              float64
# social_media_hours               float64
# netflix_hours                    float64
# part_time_job                     object
# attendance_percentage            float64
# sleep_hours                      float64
# diet_quality                      object
# exercise_frequency                 int64
# parental_education_level          object
# internet_quality                  object
# mental_health_rating             float64
# extracurricular_participation     object
# previous_gpa                     float64
# semester                           int64
# stress_level                     float64
# dropout_risk                      object
# social_activity                    int64
# screen_time                      float64
# study_environment                 object
# ...

# %% [markdown]
# # Part 2: Selecting and Filtering Data
# **How do you select and display only the student_id and exam_score columns?**

# %%
df[['student_id', 'exam_score']]
# Out:
#        student_id  exam_score
# 0          100000         100
# 1          100001          99
# 2          100002          98
# 3          100003         100
# 4          100004          98
# ...           ...         ...
# 79995      179995          88
# 79996      179996          52
# 79997      179997          89
# 79998      179998          96
# 79999      179999         100
#
# [80000 rows x 2 columns]

# %% [markdown]
# **How do you select all columns except student_id?**

# %%
df.loc[:, df.columns != 'student_id']
# Out:
#        age  gender             major  study_hours_per_day  social_media_hours  \
# 0       26    Male  Computer Science             7.645367                 3.0
# 1       28    Male              Arts             5.700000                 0.5
# 2       17    Male              Arts             2.400000                 4.2
# 3       27   Other        Psychology             3.400000                 4.6
# 4       25  Female          Business             4.700000                 0.8
# ...    ...     ...               ...                  ...                 ...
# 79995   16    Male       Engineering             3.700000                 2.1
# 79996   16  Female          Business             1.200000                 0.4
# 79997   26  Female              Arts             4.100000                 1.6
# 79998   23   Other           Biology             3.800000                 0.6
# 79999   25   Other       Engineering             3.000000                 4.5
#
# ...

# %% [markdown]
# **How do you filter the DataFrame to show only students older than 25 years?**

# %%
df[df['age'] > 25]
# Out:
#        student_id  age  gender             major  study_hours_per_day  \
# 0          100000   26    Male  Computer Science             7.645367
# 1          100001   28    Male              Arts             5.700000
# 3          100003   27   Other        Psychology             3.400000
# 8          100008   28  Female        Psychology             0.600000
# 11         100011   26   Other           Biology             3.900000
# ...           ...  ...     ...               ...                  ...
# 79979      179979   26    Male           Biology             7.400000
# 79987      179987   28   Other  Computer Science             5.248196
# 79988      179988   28  Female       Engineering             2.700000
# 79993      179993   28    Male              Arts             1.300000
# 79997      179997   26  Female              Arts             4.100000
#
#        social_media_hours  netflix_hours part_time_job  attendance_percentage  \
# ...

# %% [markdown]
# **How do you filter the DataFrame to show only female students?**

# %%
df[df['gender'] == 'Female']
# Out:
#        student_id  age  gender             major  study_hours_per_day  \
# 4          100004   25  Female          Business             4.700000
# 5          100005   17  Female       Engineering             4.200000
# 8          100008   28  Female        Psychology             0.600000
# 12         100012   19  Female          Business             4.700000
# 13         100013   24  Female          Business             7.400000
# ...           ...  ...     ...               ...                  ...
# 79982      179982   23  Female  Computer Science             3.572364
# 79988      179988   28  Female       Engineering             2.700000
# 79991      179991   24  Female       Engineering             0.000000
# 79996      179996   16  Female          Business             1.200000
# 79997      179997   26  Female              Arts             4.100000
#
#        social_media_hours  netflix_hours part_time_job  attendance_percentage  \
# ...

# %% [markdown]
# **How do you filter the DataFrame to show students who are 'Male' AND have an exam_score greater than 90?**

# %%
df[   (df['gender'] == 'Male') & (df['exam_score'] > 90)   ]
# Out:
#        student_id  age gender             major  study_hours_per_day  \
# 0          100000   26   Male  Computer Science             7.645367
# 1          100001   28   Male              Arts             5.700000
# 2          100002   17   Male              Arts             2.400000
# 6          100006   19   Male        Psychology             4.100000
# 9          100009   19   Male       Engineering             5.200000
# ...           ...  ...    ...               ...                  ...
# 79962      179962   27   Male  Computer Science            10.197103
# 79964      179964   20   Male           Biology             3.100000
# 79975      179975   25   Male  Computer Science             6.905902
# 79979      179979   26   Male           Biology             7.400000
# 79990      179990   25   Male       Engineering             2.200000
#
#        social_media_hours  netflix_hours part_time_job  attendance_percentage  \
# ...

# %% [markdown]
# **How do you filter the DataFrame to show students who are 'Female' OR have a dropout_risk of 'Yes'?**

# %%
df[(df['gender'] == 'Female') | (df['dropout_risk'] == 'Yes')]
# Out:
#        student_id  age  gender             major  study_hours_per_day  \
# 4          100004   25  Female          Business             4.700000
# 5          100005   17  Female       Engineering             4.200000
# 8          100008   28  Female        Psychology             0.600000
# 12         100012   19  Female          Business             4.700000
# 13         100013   24  Female          Business             7.400000
# ...           ...  ...     ...               ...                  ...
# 79982      179982   23  Female  Computer Science             3.572364
# 79988      179988   28  Female       Engineering             2.700000
# 79991      179991   24  Female       Engineering             0.000000
# 79996      179996   16  Female          Business             1.200000
# 79997      179997   26  Female              Arts             4.100000
#
#        social_media_hours  netflix_hours part_time_job  attendance_percentage  \
# ...

# %% [markdown]
# **How do you find all students whose major is 'Computer Science'?**

# %%
df[df['major'] == 'Computer Science']
# Out:
#        student_id  age  gender             major  study_hours_per_day  \
# 0          100000   26    Male  Computer Science             7.645367
# 15         100015   17  Female  Computer Science             3.527595
# 23         100023   23    Male  Computer Science             3.279126
# 29         100029   18  Female  Computer Science             3.837870
# 30         100030   26   Other  Computer Science             7.606318
# ...           ...  ...     ...               ...                  ...
# 79981      179981   21   Other  Computer Science             4.125943
# 79982      179982   23  Female  Computer Science             3.572364
# 79984      179984   22    Male  Computer Science             6.268124
# 79987      179987   28   Other  Computer Science             5.248196
# 79992      179992   20   Other  Computer Science             5.627152
#
#        social_media_hours  netflix_hours part_time_job  attendance_percentage  \
# ...

# %% [markdown]
# # Part 3: Basic Statistics and Aggregation
# **What is the average exam_score for all students?**

# %%
average = df['exam_score'].mean()
print('The average in exam score for all students is', average)
# Out:
# The average in exam score for all students is 89.14135

# %% [markdown]
# **What is the maximum study_hours_per_day recorded?**

# %%
mxhr = df.study_hours_per_day.max()
print('The maximum study_hours_per_day is', mxhr)
# Out:
# The maximum study_hours_per_day is 12.0

# %% [markdown]
# **What is the minimum netflix_hours recorded?**

# %%
print('Minimum netflix_hours:', df.netflix_hours.min())
# Out:
# Minimum netflix_hours: 0.0

# %% [markdown]
# **How many unique values are there in the gender column?**

# %%
gen_count = len(df.gender.unique())
print('Total :', gen_count)
# Out:
# Total : 3

# %% [markdown]
# **How do you count the occurrences of each major in the dataset?**

# %%
df['major'].value_counts()
# Out:
# major
# Arts                13505
# Psychology          13437
# Computer Science    13352
# Business            13276
# Engineering         13229
# Biology             13201
# Name: count, dtype: int64

# %% [markdown]
# **What is the average exam_score for each gender?**

# %%
male = df[df['gender'] == 'Male'].exam_score.mean()
female = df[df['gender'] == 'Female'].exam_score.mean()
other = df[df['gender'] == 'Other'].exam_score.mean()


print(f'The avarage exam score for male is {male}')
print(f'The avarage exam score for female is {female}')
print(f'The avarage exam score for other is {other}')
# Out:
# The avarage exam score for male is 89.15203386021425
# The avarage exam score for female is 89.10844411158959
# The avarage exam score for other is 89.16366507500845

# %% [markdown]
# **What is the average study_hours_per_day for students with and without a part_time_job?**

# %%
df
# Out:
#        student_id  age  gender             major  study_hours_per_day  \
# 0          100000   26    Male  Computer Science             7.645367
# 1          100001   28    Male              Arts             5.700000
# 2          100002   17    Male              Arts             2.400000
# 3          100003   27   Other        Psychology             3.400000
# 4          100004   25  Female          Business             4.700000
# ...           ...  ...     ...               ...                  ...
# 79995      179995   16    Male       Engineering             3.700000
# 79996      179996   16  Female          Business             1.200000
# 79997      179997   26  Female              Arts             4.100000
# 79998      179998   23   Other           Biology             3.800000
# 79999      179999   25   Other       Engineering             3.000000
#
#        social_media_hours  netflix_hours part_time_job  attendance_percentage  \
# ...

# %%
who_have_job = df[df['part_time_job']=='Yes']
no_job =  df[df['part_time_job']=='No']

st_col = who_have_job['study_hours_per_day'].mean()
st_col_no = no_job['study_hours_per_day'].mean()

print('Have part-time job', st_col)
print("Don't have part-time job", st_col_no)
# Out:
# Have part-time job 4.168088834454209
# Don't have part-time job 4.180626416572783

# %% [markdown]
# **How do you find the total number of students for each parental_education_level?**

# %%
print(df['parental_education_level'].value_counts())
# Out:
# parental_education_level
# Some College    16115
# High School     16106
# Bachelor        15986
# Master          15908
# PhD             15885
# Name: count, dtype: int64

# %% [markdown]
# # Part 4: Data Manipulation and More
# **How do you check for any missing values in the entire DataFrame?**

# %%
df.isnull().count()
# Out:
# student_id                       80000
# age                              80000
# gender                           80000
# major                            80000
# study_hours_per_day              80000
# social_media_hours               80000
# netflix_hours                    80000
# part_time_job                    80000
# attendance_percentage            80000
# sleep_hours                      80000
# diet_quality                     80000
# exercise_frequency               80000
# parental_education_level         80000
# internet_quality                 80000
# mental_health_rating             80000
# extracurricular_participation    80000
# previous_gpa                     80000
# semester                         80000
# stress_level                     80000
# dropout_risk                     80000
# social_activity                  80000
# screen_time                      80000
# study_environment                80000
# access_to_tutoring               80000
# ...

# %% [markdown]
# **How do you check for missing values specifically in the mental_health_rating column?**

# %%
df.mental_health_rating.isnull().value_counts()
# Out:
# mental_health_rating
# False    80000
# Name: count, dtype: int64

# %% [markdown]
# **How would you rename the column study_hours_per_day to daily_study_hours? (Just show the code for renaming, no need to save it permanently for this question).**

# %%
df.rename(columns={'study_hours_per_day': 'daily_study_hours'})
# Out:
#        student_id  age  gender             major  daily_study_hours  \
# 0          100000   26    Male  Computer Science           7.645367
# 1          100001   28    Male              Arts           5.700000
# 2          100002   17    Male              Arts           2.400000
# 3          100003   27   Other        Psychology           3.400000
# 4          100004   25  Female          Business           4.700000
# ...           ...  ...     ...               ...                ...
# 79995      179995   16    Male       Engineering           3.700000
# 79996      179996   16  Female          Business           1.200000
# 79997      179997   26  Female              Arts           4.100000
# 79998      179998   23   Other           Biology           3.800000
# 79999      179999   25   Other       Engineering           3.000000
#
#        social_media_hours  netflix_hours part_time_job  attendance_percentage  \
# ...

# %% [markdown]
# **How do you sort the DataFrame by exam_score in descending order?**

# %%
df.sort_values(by='exam_score', ascending=False)
# Out:
#        student_id  age  gender             major  study_hours_per_day  \
# 79983      179983   23   Other              Arts             5.400000
# 79979      179979   26    Male           Biology             7.400000
# 79977      179977   16   Other              Arts             3.100000
# 79974      179974   17   Other              Arts             3.000000
# 79971      179971   23  Female  Computer Science             6.475817
# ...           ...  ...     ...               ...                  ...
# 70912      170912   25  Female              Arts             0.900000
# 32164      132164   16  Female        Psychology             2.900000
# 6722       106722   21   Other           Biology             1.300000
# 57083      157083   24  Female       Engineering             0.000000
# 77639      177639   26    Male       Engineering             0.000000
#
#        social_media_hours  netflix_hours part_time_job  attendance_percentage  \
# ...

# %%
df.sort_values(by='exam_score', ascending=False)
# Out:
#        student_id  age  gender             major  study_hours_per_day  \
# 79983      179983   23   Other              Arts             5.400000
# 79979      179979   26    Male           Biology             7.400000
# 79977      179977   16   Other              Arts             3.100000
# 79974      179974   17   Other              Arts             3.000000
# 79971      179971   23  Female  Computer Science             6.475817
# ...           ...  ...     ...               ...                  ...
# 70912      170912   25  Female              Arts             0.900000
# 32164      132164   16  Female        Psychology             2.900000
# 6722       106722   21   Other           Biology             1.300000
# 57083      157083   24  Female       Engineering             0.000000
# 77639      177639   26    Male       Engineering             0.000000
#
#        social_media_hours  netflix_hours part_time_job  attendance_percentage  \
# ...

# %% [markdown]
# **How do you sort the DataFrame first by major (ascending) and then by exam_score (descending)?**

# %%
df.sort_values(by=['major', 'exam_score'], ascending=[True, False])
# Out:
#        student_id  age  gender       major  study_hours_per_day  \
# 10         100010   16   Other        Arts                  0.0
# 39         100039   17   Other        Arts                  7.4
# 42         100042   28   Other        Arts                  5.9
# 104        100104   19  Female        Arts                  6.3
# 117        100117   23  Female        Arts                  4.8
# ...           ...  ...     ...         ...                  ...
# 36774      136774   26   Other  Psychology                  0.3
# 71080      171080   16   Other  Psychology                  1.3
# 26761      126761   20    Male  Psychology                  3.1
# 45017      145017   20    Male  Psychology                  0.0
# 32164      132164   16  Female  Psychology                  2.9
#
#        social_media_hours  netflix_hours part_time_job  attendance_percentage  \
# 10                    2.7            0.2            No                   44.1
# ...

# %% [markdown]
# **How do you create a new column called total_screen_time by adding social_media_hours and netflix_hours?**

# %%
df['total_screen_time'] = df['social_media_hours'] + df['netflix_hours']

# %%
df['total_screen_time'] = df.social_media_hours + df.netflix_hours

df
# Out:
#        student_id  age  gender             major  study_hours_per_day  \
# 0          100000   26    Male  Computer Science             7.645367
# 1          100001   28    Male              Arts             5.700000
# 2          100002   17    Male              Arts             2.400000
# 3          100003   27   Other        Psychology             3.400000
# 4          100004   25  Female          Business             4.700000
# ...           ...  ...     ...               ...                  ...
# 79995      179995   16    Male       Engineering             3.700000
# 79996      179996   16  Female          Business             1.200000
# 79997      179997   26  Female              Arts             4.100000
# 79998      179998   23   Other           Biology             3.800000
# 79999      179999   25   Other       Engineering             3.000000
#
#        social_media_hours  netflix_hours part_time_job  attendance_percentage  \
# ...

# %% [markdown]
# **How do you find the average exam_score for students based on their diet_quality and exercise_frequency? (Hint: Use groupby with multiple columns).**

# %%
df.groupby(['diet_quality', 'exercise_frequency'])['exam_score'].mean()
# Out:
# diet_quality  exercise_frequency
# Fair          0                     87.913238
#               1                     88.355279
#               2                     88.302017
#               3                     89.089860
#               4                     89.441055
#               5                     89.643723
#               6                     90.346009
#               7                     91.050766
# Good          0                     87.285539
#               1                     87.951283
#               2                     88.190319
#               3                     88.830163
#               4                     89.593725
#               5                     89.915667
#               6                     90.198866
#               7                     90.280040
# Poor          0                     87.681081
#               1                     88.065814
#               2                     88.617009
#               3                     89.287392
# ...

# %%
 df2 = df.groupby(['diet_quality', 'exercise_frequency'])['exam_score'].mean()
df2 = pd.DataFrame(df2)
df2
# Out:
#                                  exam_score
# diet_quality exercise_frequency
# Fair         0                    87.913238
#              1                    88.355279
#              2                    88.302017
#              3                    89.089860
#              4                    89.441055
#              5                    89.643723
#              6                    90.346009
#              7                    91.050766
# Good         0                    87.285539
#              1                    87.951283
#              2                    88.190319
#              3                    88.830163
#              4                    89.593725
#              5                    89.915667
#              6                    90.198866
#              7                    90.280040
# Poor         0                    87.681081
#              1                    88.065814
#              2                    88.617009
#              3                    89.287392
# ...

# %% [markdown]
# **How do you select rows where dropout_risk is 'Yes' and calculate the average stress_level for these students?**

# %%
df_stress = df[df['dropout_risk'] == 'Yes'].loc[:,['student_id', 'dropout_risk', 'stress_level']]
df_stress.head(10)
# Out:
#      student_id dropout_risk  stress_level
# 24       100024          Yes           9.5
# 50       100050          Yes           8.1
# 118      100118          Yes          10.0
# 157      100157          Yes           8.2
# 239      100239          Yes           8.7
# 240      100240          Yes           8.3
# 262      100262          Yes           8.6
# 291      100291          Yes           8.2
# 351      100351          Yes           8.7
# 535      100535          Yes           8.3

# %%
print('Average stress_level for these students:', df_stress.stress_level.mean())
# Out:
# Average stress_level for these students: 8.889380530973451
